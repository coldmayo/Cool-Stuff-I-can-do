# %% [markdown]
# # Manipulating Qubits

# %%
import qiskit

# %% [markdown]
# Below is an example of a simple quantum circuit (used on quantum computers) next to a classical circuit (used on binary or regular computers). The "x" in the first line of output means that the qubit is in the state 1 while the others are at state 0.

# %%
from qiskit import(
  QuantumCircuit,
  execute)
from qiskit.visualization import plot_histogram
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
#In the parenthesis the first number represents how many Quantum circuts will be used while the next number reprents how
#many classical circuts are used
circut=QuantumCircuit(1,1)
circut.x(0)
circut.draw()
# Out:
# <pre style="word-wrap: normal;white-space: pre;background: #fff0;line-height: 1.1;font-family: &quot;Courier New&quot;,Courier,monospace">        ┌───┐
# q_0: |0>┤ X ├
#         └───┘
#  c_0: 0 ═════
#              </pre>

# %% [markdown]
# In this cell I used the statevector_simulator to do the same thing as above. The only thing different is the qubits are drawn out.

# %%
from qiskit import *
from qiskit.tools.visualization import plot_bloch_multivector
#here we make a circut with one classical bit and one Quantum bit
circut=QuantumCircuit(3)
#This makes whatever number inside parenthesis in state one
#If you do multiple of these commands then 
circut.x(0)
simulator=Aer.get_backend("statevector_simulator")
result = execute(circut, backend=simulator).result()
statevector=result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %% [markdown]
# I found the code to make more appealing drawings.

# %%
circut.draw(output='mpl')

# %% [markdown]
# Although quantum computers can be in states 0 and 1 it's even cooler when you put the qubits into superposition. That is done using gates. All of the types of gates can be found in the IBM Q Experience glossary.

# %%
import numpy as np
q = QuantumRegister(4)
qantCur = QuantumCircuit(q)
#ry represents the gate that is used to ditermine were the arrow points
qantCur.ry(np.pi/2,q)
qantCur.x(0)
qantCur.ry(np.pi/3,q)
qantCur.x(1)
qantCur.ry(np.pi/4,q)
qantCur.x(2)
qantCur.ry(np.pi/5,q)
qantCur.x(3)
simulator=Aer.get_backend("statevector_simulator")
result = execute(qantCur, backend=simulator).result()
statevector=result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [-0.21640473+5.19167168e-17j  0.45370195-1.08845660e-16j
#  -0.31487084+7.55392917e-17j  0.66014043-1.58371418e-16j
#  -0.04010825+1.31696064e-17j  0.08408869-2.76106539e-17j
#  -0.05835786+1.91618962e-17j  0.1223498 -4.01737508e-17j
#   0.10321976-1.21222286e-17j -0.21640473+2.54147808e-17j
#   0.15018568-1.76379521e-17j -0.31487084+3.69787356e-17j
#   0.01913065-3.93875085e-18j -0.04010825+8.25776287e-18j
#   0.02783527-5.73091804e-18j -0.05835786+1.20151195e-17j]

# %% [markdown]
# This is what the circuit would look like

# %%
qantCur.draw(output='mpl')

# %% [markdown]
# Here I replaced x with y and z.

# %%
q = QuantumRegister(3)
qantCur = QuantumCircuit(q)
#ry represents the gate that is used to ditermine were the arrow points
qantCur.rx(np.pi/2,q)
qantCur.z(0)
qantCur.y(1)
qantCur.x(2)
simulator=Aer.get_backend("statevector_simulator")
result = execute(qantCur, backend=simulator).result()
statevector=result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [-4.32978028e-17+3.53553391e-01j -3.53553391e-01-6.49467042e-17j
#   3.53553391e-01+2.16489014e-17j -4.32978028e-17+3.53553391e-01j
#  -3.53553391e-01-2.16489014e-17j  4.32978028e-17-3.53553391e-01j
#   0.00000000e+00+3.53553391e-01j -3.53553391e-01-2.16489014e-17j]

# %%
qantCur.draw(output="mpl")

# %% [markdown]
# Here I made a histogram ploting the Bell State of all 4 qubits from the 5th cell. Bell State is a maximally entangled quantum state of two qubits. (I got the definition from quantiki.org)

# %%
from qiskit.tools.visualization import plot_histogram, plot_state_city
q = QuantumRegister(4)
qantCur = QuantumCircuit(q)
#ry represents the gate that is used to ditermine were the arrow points
qantCur.ry(np.pi/2,q)
qantCur.x(0)
qantCur.ry(np.pi/3,q)
qantCur.x(1)
qantCur.ry(np.pi/4,q)
qantCur.x(2)
qantCur.ry(np.pi/5,q)
qantCur.x(3)

# Select the StatevectorSimulator from the Aer provider
simulator = Aer.get_backend('statevector_simulator')

# Execute and get counts
result = execute(circ, simulator).result()
statevector = result.get_statevector(circ)
plot_state_city(statevector, title='Bell state')
